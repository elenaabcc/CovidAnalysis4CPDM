# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import plotly.io as pio
import plotly.express as px
pio.renderers.default='plotly_mimetype+notebook'

# %%
icu_data=pd.read_csv(r'C:\Users\strag\Documents\GitHub\CovidAnalysis4CPDM\PROGETTO\icu dataframe.csv')
icu_data
# Out:
#        country                           indicator        date year_week  \
# 0      Austria            Daily hospital occupancy  2020-04-01  2020-W14
# 1      Austria            Daily hospital occupancy  2020-04-02  2020-W14
# 2      Austria            Daily hospital occupancy  2020-04-03  2020-W14
# 3      Austria            Daily hospital occupancy  2020-04-04  2020-W14
# 4      Austria            Daily hospital occupancy  2020-04-05  2020-W14
# ...        ...                                 ...         ...       ...
# 32806   Sweden  Weekly new ICU admissions per 100k  2021-12-19  2021-W50
# 32807   Sweden  Weekly new ICU admissions per 100k  2021-12-26  2021-W51
# 32808   Sweden  Weekly new ICU admissions per 100k  2022-01-02  2021-W52
# 32809   Sweden  Weekly new ICU admissions per 100k  2022-01-09  2022-W01
# 32810   Sweden  Weekly new ICU admissions per 100k  2022-01-16  2022-W02
#
#             value                               source  \
# ...

# %%
#MEAN NUMBER OF COVID PATIENTS IN HOSPITAL AND ICU OCCUPANCY FROM THE BEGINNING TO NOW
icu_italy=icu_data[icu_data['country']=='Italy']
my_cond=['Daily ICU occupancy', 'Daily hospital occupancy']
icu_italy=icu_italy[icu_italy['indicator'].isin(my_cond)]
icu_italy[['Year', 'Month', 'Week']]=icu_italy['date'].str.split('-', expand=True)
icu_italy.head()
# Out:
#       country                 indicator        date year_week  value  \
# 17128   Italy  Daily hospital occupancy  2020-02-24  2020-W09  127.0
# 17129   Italy  Daily hospital occupancy  2020-02-25  2020-W09  149.0
# 17130   Italy  Daily hospital occupancy  2020-02-26  2020-W09  164.0
# 17131   Italy  Daily hospital occupancy  2020-02-27  2020-W09  304.0
# 17132   Italy  Daily hospital occupancy  2020-02-28  2020-W09  409.0
#
#                source                                  url  Year Month Week
# 17128  Country_Github  https://github.com/pcm-dpc/COVID-19  2020    02   24
# 17129  Country_Github  https://github.com/pcm-dpc/COVID-19  2020    02   25
# 17130  Country_Github  https://github.com/pcm-dpc/COVID-19  2020    02   26
# 17131  Country_Github  https://github.com/pcm-dpc/COVID-19  2020    02   27
# 17132  Country_Github  https://github.com/pcm-dpc/COVID-19  2020    02   28

# %%
#ICU AND HOSPITAL OCCUPANCY IN 2021
icu_2021=icu_italy[icu_italy.Year=='2021']
table_2021=icu_2021.pivot_table(index='Month', columns='indicator', values='value', aggfunc='mean')
table_2021.plot(kind='bar', title='ICU and hospital occupancy in 2021', color=['red', 'yellow'])
plt.ylabel('Mean')
plt.savefig('ICU and H.O. in 2021.jpeg', dpi=300, bbox_inches='tight')

# %%
icu_2020=icu_italy[icu_italy.Year=='2020']
table_update=icu_2020.pivot_table(index='Month', columns='indicator', values='value', aggfunc='mean')
table_update.plot(kind='bar', title='ICU and hospital occupancy in 2020', color=['red', 'yellow'])
plt.ylabel('Mean')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.savefig('ICU and H.O. in 2020.jpeg',dpi=300, bbox_inches='tight')
